# %% [markdown]
# # MIMIC IV Data Medical Profiles
# Generate patient clinical profile used to develop search query for relevant clinical trials.
# - Estimate age from de-identified data
# - Retrieve key relevant conditions and terms
# - Aggregate information from recent radiology reports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Load Discharge Data
# Patient clinical admission-to-discharge notes

# %%
dir = ''

# %%
# Load data
df_discharge = pd.read_csv(dir + '/discharge.csv')

# Convert charttime to pandas datetime
df_discharge['charttime'] = pd.to_datetime(df_discharge['charttime'], format='%Y-%m-%d %H:%M:%S')

# Drop fields
df_discharge = df_discharge.drop(['note_type', 'note_seq', 'storetime'], axis=1)

display(df_discharge.head())
display(df_discharge.info())
# Out:
#           note_id  subject_id   hadm_id  charttime  \
# 0  10000032-DS-21    10000032  22595853 2180-05-07
# 1  10000032-DS-22    10000032  22841357 2180-06-27
# 2  10000032-DS-23    10000032  29079034 2180-07-25
# 3  10000032-DS-24    10000032  25742920 2180-08-07
# 4  10000084-DS-17    10000084  23052089 2160-11-25
#
#                                                 text
# 0   \nName:  ___                     Unit No:   _...
# 1   \nName:  ___                     Unit No:   _...
# 2   \nName:  ___                     Unit No:   _...
# 3   \nName:  ___                     Unit No:   _...
# 4   \nName:  ___                    Unit No:   __...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331793 entries, 0 to 331792
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   note_id     331793 non-null  object
#  1   subject_id  331793 non-null  int64
#  2   hadm_id     331793 non-null  int64
#  3   charttime   331793 non-null  datetime64[ns]
#  4   text        331793 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 12.7+ MB
# None

# %% [markdown]
# # 2. ICD

# %%
# Load data
df_icd = pd.read_csv(dir + '/diagnoses_icd.csv')

# Rename for clarity
df_icd = df_icd.rename(columns={'seq_num': 'icd_priority'})

df_icd.head()
# Out:
#    subject_id   hadm_id  icd_priority icd_code  icd_version
# 0    10000032  22595853             1     5723            9
# 1    10000032  22595853             2    78959            9
# 2    10000032  22595853             3     5715            9
# 3    10000032  22595853             4    07070            9
# 4    10000032  22595853             5      496            9

# %%
# Retain only priority diagnosis codes

n_priority = 5  #TODO

# Filter to retain priority codes
df_icd = df_icd[df_icd.icd_priority <= 5]

# %%
# Join
df_discharge_v1 = pd.merge(df_discharge,
                            df_icd,
                            on=['subject_id', 'hadm_id'], how='left')

df_discharge_v1
# Out:
#                 note_id  subject_id   hadm_id  charttime  \
# 0        10000032-DS-21    10000032  22595853 2180-05-07
# 1        10000032-DS-21    10000032  22595853 2180-05-07
# 2        10000032-DS-21    10000032  22595853 2180-05-07
# 3        10000032-DS-21    10000032  22595853 2180-05-07
# 4        10000032-DS-21    10000032  22595853 2180-05-07
# ...                 ...         ...       ...        ...
# 1591605   19999987-DS-2    19999987  23865745 2145-11-11
# 1591606   19999987-DS-2    19999987  23865745 2145-11-11
# 1591607   19999987-DS-2    19999987  23865745 2145-11-11
# 1591608   19999987-DS-2    19999987  23865745 2145-11-11
# 1591609   19999987-DS-2    19999987  23865745 2145-11-11
#
#                                                       text  icd_priority  \
# 0         \nName:  ___                     Unit No:   _...           1.0
# 1         \nName:  ___                     Unit No:   _...           2.0
# 2         \nName:  ___                     Unit No:   _...           3.0
# 3         \nName:  ___                     Unit No:   _...           4.0
# 4         \nName:  ___                     Unit No:   _...           5.0
# ...                                                    ...           ...
# 1591605   \nName:  ___                    Unit No:   __...           1.0
# 1591606   \nName:  ___                    Unit No:   __...           2.0
# 1591607   \nName:  ___                    Unit No:   __...           3.0
# 1591608   \nName:  ___                    Unit No:   __...           4.0
# 1591609   \nName:  ___                    Unit No:   __...           5.0
#
#         icd_code  icd_version
# 0           5723          9.0
# 1          78959          9.0
# 2           5715          9.0
# 3          07070          9.0
# 4            496          9.0
# ...          ...          ...
# 1591605      431          9.0
# 1591606     3485          9.0
# 1591607    20280          9.0
# 1591608     5849          9.0
# 1591609     5990          9.0
#
# [1591610 rows x 8 columns]

# %% [markdown]
# ## Load ICD Code Descriptions

# %%
def read_icd_descriptions(file_path):
  '''
  Reads ICD desc files txt and returns lookup table. Each entry is a code
  and description, with everything separated by non-delimiting white space.
  Encoding is latin-1.
  '''

  codes = []
  descriptions = []


  with open(file_path, 'r', encoding='latin-1') as f:
      for line in f:
          parts = line.strip().split(maxsplit=1)  # Strip whitespace and split
          if parts:
              codes.append(parts[0])
              descriptions.append(parts[1] if len(parts) > 1 else "")
          else:
              codes.append("")
              descriptions.append("")

  return pd.DataFrame({'icd_code': codes, 'icd_description': descriptions})

# %%
# Read ICD 9
ICD9_desc_2015 = read_icd_descriptions(dir + '/CMS32_DESC_LONG_DX_2015.txt')
# Read ICD 10
ICD10_desc_2023 = read_icd_descriptions(dir + '/icd10cm_codes_2023.txt')

display(ICD9_desc_2015)
display(ICD10_desc_2023)
# Out:
#       icd_code                                    icd_description
# 0         0010                     Cholera due to vibrio cholerae
# 1         0011              Cholera due to vibrio cholerae el tor
# 2         0019                               Cholera, unspecified
# 3         0020                                      Typhoid fever
# 4         0021                                Paratyphoid fever A
# ...        ...                                                ...
# 14562    V9129  Quadruplet gestation, unable to determine numb...
# 14563    V9190  Other specified multiple gestation, unspecifie...
# 14564    V9191  Other specified multiple gestation, with two o...
# 14565    V9192  Other specified multiple gestation, with two o...
# 14566    V9199  Other specified multiple gestation, unable to ...
#
# [14567 rows x 2 columns]
#       icd_code                                    icd_description
# 0         A000  Cholera due to Vibrio cholerae 01, biovar chol...
# 1         A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 2         A009                               Cholera, unspecified
# 3        A0100                         Typhoid fever, unspecified
# 4        A0101                                 Typhoid meningitis
# ...        ...                                                ...
# 73669    Z9981                  Dependence on supplemental oxygen
# 73670    Z9989  Dependence on other enabling machines and devices
# 73671     U070                            Vaping-related disorder
# 73672     U071                                           COVID-19
# 73673     U099               Post COVID-19 condition, unspecified
#
# [73674 rows x 2 columns]

# %% [markdown]
# ## Translate ICD
# Add descriptions using ICD lookup
# - Using latest version, 2015, for ICD 9
# - Using active version as of the end date of dataset, 2023, for ICD 10

# %%
# Append descriptions with respect to ICD version

df_discharge_v1_icd9 = pd.merge(df_discharge_v1[df_discharge_v1['icd_version'] == 9],
         ICD9_desc_2015,
         on='icd_code',
         how='left')

df_discharge_v1_icd10 = pd.merge(df_discharge_v1[df_discharge_v1['icd_version'] == 10],
         ICD10_desc_2023,
         on='icd_code',
         how='left')

# Cases with no ICD codes
df_discharge_v1_icdnone = df_discharge_v1[(df_discharge_v1['icd_version'] != 9) & (df_discharge_v1['icd_version'] != 10)]

# Discharge notes with joined icd decscriptions
df_discharge_v2 = pd.concat([df_discharge_v1_icd9, df_discharge_v1_icd10, df_discharge_v1_icdnone], ignore_index=True)

# Drop
df_discharge_v2 = df_discharge_v2.drop(['icd_code', 'icd_version'], axis=1)

# Delete df
del df_discharge_v1
del df_discharge_v1_icd9
del df_discharge_v1_icd10
del df_discharge_v1_icdnone

df_discharge_v2
# Out:
#                 note_id  subject_id   hadm_id  charttime  \
# 0        10000032-DS-21    10000032  22595853 2180-05-07
# 1        10000032-DS-21    10000032  22595853 2180-05-07
# 2        10000032-DS-21    10000032  22595853 2180-05-07
# 3        10000032-DS-21    10000032  22595853 2180-05-07
# 4        10000032-DS-21    10000032  22595853 2180-05-07
# ...                 ...         ...       ...        ...
# 1591605   19965819-DS-5    19965819  28425094 2164-02-10
# 1591606   19965819-DS-6    19965819  20088669 2164-02-16
# 1591607   19973723-DS-6    19973723  27287088 2150-12-07
# 1591608  19979521-DS-11    19979521  24906806 2200-09-08
# 1591609  19998843-DS-18    19998843  29554106 2187-02-08
#
#                                                       text  icd_priority  \
# 0         \nName:  ___                     Unit No:   _...           1.0
# 1         \nName:  ___                     Unit No:   _...           2.0
# 2         \nName:  ___                     Unit No:   _...           3.0
# 3         \nName:  ___                     Unit No:   _...           4.0
# 4         \nName:  ___                     Unit No:   _...           5.0
# ...                                                    ...           ...
# 1591605   \nName:  ___                   Unit No:   ___...           NaN
# 1591606   \nName:  ___                   Unit No:   ___...           NaN
# 1591607   \nName:  ___                 Unit No:   ___\n...           NaN
# 1591608   \nName:  ___                    Unit No:   __...           NaN
# 1591609   \nName:  ___                    Unit No:   __...           NaN
#
#                                            icd_description
# 0                                      Portal hypertension
# 1                                            Other ascites
# 2            Cirrhosis of liver without mention of alcohol
# 3        Unspecified viral hepatitis C without hepatic ...
# 4        Chronic airway obstruction, not elsewhere clas...
# ...                                                    ...
# 1591605                                                NaN
# 1591606                                                NaN
# 1591607                                                NaN
# 1591608                                                NaN
# 1591609                                                NaN
#
# [1591610 rows x 7 columns]

# %% [markdown]
# ## Aggregate ICD

# %%
# Sort by subject_hadm and priority
df_aggregate_icd_desc = df_discharge_v2.sort_values(by=['subject_id', 'hadm_id', 'icd_priority'])

# Aggregate diagnosis texts into a list, ordered by priority
df_aggregate_icd_desc = df_aggregate_icd_desc.groupby(['subject_id', 'hadm_id'])['icd_description'].apply(list).reset_index(name='ordered_diagnoses')

df_aggregate_icd_desc
# Out:
#         subject_id   hadm_id  \
# 0         10000032  22595853
# 1         10000032  22841357
# 2         10000032  25742920
# 3         10000032  29079034
# 4         10000084  23052089
# ...            ...       ...
# 331788    19999828  25744818
# 331789    19999828  29734428
# 331790    19999840  21033226
# 331791    19999840  26071774
# 331792    19999987  23865745
#
#                                         ordered_diagnoses
# 0       [Portal hypertension, Other ascites, Cirrhosis...
# 1       [Unspecified viral hepatitis C with hepatic co...
# 2       [Chronic hepatitis C without mention of hepati...
# 3       [Other iatrogenic hypotension, Chronic hepatit...
# 4       [Neurocognitive disorder with Lewy bodies, Dem...
# ...                                                   ...
# 331788  [Infection following a procedure, superficial ...
# 331789  [Disruption of external operation (surgical) w...
# 331790  [Grand mal status, Acute respiratory failure, ...
# 331791  [Cerebral artery occlusion, unspecified with c...
# 331792  [Intracerebral hemorrhage, Cerebral edema, Oth...
#
# [331793 rows x 3 columns]

# %%
# Join aggregate table back to main discharge table
df_discharge_v3 = pd.merge(df_discharge,
                            df_aggregate_icd_desc,
                            on=['subject_id', 'hadm_id'], how='left')

# delete df
del df_discharge_v2
del df_aggregate_icd_desc


df_discharge_v3
# Out:
#                note_id  subject_id   hadm_id  charttime  \
# 0       10000032-DS-21    10000032  22595853 2180-05-07
# 1       10000032-DS-22    10000032  22841357 2180-06-27
# 2       10000032-DS-23    10000032  29079034 2180-07-25
# 3       10000032-DS-24    10000032  25742920 2180-08-07
# 4       10000084-DS-17    10000084  23052089 2160-11-25
# ...                ...         ...       ...        ...
# 331788   19999828-DS-6    19999828  29734428 2147-08-04
# 331789   19999828-DS-7    19999828  25744818 2149-01-18
# 331790  19999840-DS-20    19999840  26071774 2164-07-28
# 331791  19999840-DS-21    19999840  21033226 2164-09-17
# 331792   19999987-DS-2    19999987  23865745 2145-11-11
#
#                                                      text  \
# 0        \nName:  ___                     Unit No:   _...
# 1        \nName:  ___                     Unit No:   _...
# 2        \nName:  ___                     Unit No:   _...
# 3        \nName:  ___                     Unit No:   _...
# 4        \nName:  ___                    Unit No:   __...
# ...                                                   ...
# 331788   \nName:  ___                   Unit No:   ___...
# 331789   \nName:  ___                   Unit No:   ___...
# 331790   \nName:  ___                  Unit No:   ___\...
# 331791   \nName:  ___                  Unit No:   ___\...
# 331792   \nName:  ___                    Unit No:   __...
#
#                                         ordered_diagnoses
# 0       [Portal hypertension, Other ascites, Cirrhosis...
# 1       [Unspecified viral hepatitis C with hepatic co...
# 2       [Other iatrogenic hypotension, Chronic hepatit...
# 3       [Chronic hepatitis C without mention of hepati...
# 4       [Neurocognitive disorder with Lewy bodies, Dem...
# ...                                                   ...
# 331788  [Disruption of external operation (surgical) w...
# 331789  [Infection following a procedure, superficial ...
# 331790  [Cerebral artery occlusion, unspecified with c...
# 331791  [Grand mal status, Acute respiratory failure, ...
# 331792  [Intracerebral hemorrhage, Cerebral edema, Oth...
#
# [331793 rows x 6 columns]

# %% [markdown]
# # 3. Patient Demographics

# %%
# Load data
df_patients = pd.read_csv(dir + '/patients.csv')

df_patients
# Out:
#         subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0         10000032      F          52         2180       2014 - 2016
# 1         10000048      F          23         2126       2008 - 2010
# 2         10000058      F          33         2168       2020 - 2022
# 3         10000068      F          19         2160       2008 - 2010
# 4         10000084      M          72         2160       2017 - 2019
# ...            ...    ...         ...          ...               ...
# 364622    19999828      F          46         2147       2017 - 2019
# 364623    19999829      F          28         2186       2008 - 2010
# 364624    19999840      M          58         2164       2008 - 2010
# 364625    19999914      F          49         2158       2017 - 2019
# 364626    19999987      F          57         2145       2011 - 2013
#
#                dod
# 0       2180-09-09
# 1              NaN
# 2              NaN
# 3              NaN
# 4       2161-02-13
# ...            ...
# 364622         NaN
# 364623         NaN
# 364624  2164-09-17
# 364625         NaN
# 364626         NaN
#
# [364627 rows x 6 columns]

# %%
# Assume first year in anchor group is anchor origin year
df_patients['anchor_origin_year'] = df_patients['anchor_year_group'].str[:4].astype(int)
# Estimate birth year
df_patients['birth_year'] = df_patients['anchor_origin_year'] - df_patients['anchor_age']

# Calculate the offset per patient
df_patients['offset'] = df_patients['anchor_year'] - df_patients['anchor_origin_year']

# Display
display(df_patients)
# Out:
#         subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0         10000032      F          52         2180       2014 - 2016
# 1         10000048      F          23         2126       2008 - 2010
# 2         10000058      F          33         2168       2020 - 2022
# 3         10000068      F          19         2160       2008 - 2010
# 4         10000084      M          72         2160       2017 - 2019
# ...            ...    ...         ...          ...               ...
# 364622    19999828      F          46         2147       2017 - 2019
# 364623    19999829      F          28         2186       2008 - 2010
# 364624    19999840      M          58         2164       2008 - 2010
# 364625    19999914      F          49         2158       2017 - 2019
# 364626    19999987      F          57         2145       2011 - 2013
#
#                dod  anchor_origin_year  birth_year  offset
# 0       2180-09-09                2014        1962     166
# 1              NaN                2008        1985     118
# 2              NaN                2020        1987     148
# 3              NaN                2008        1989     152
# 4       2161-02-13                2017        1945     143
# ...            ...                 ...         ...     ...
# 364622         NaN                2017        1971     130
# 364623         NaN                2008        1980     178
# 364624  2164-09-17                2008        1950     156
# 364625         NaN                2017        1968     141
# 364626         NaN                2011        1954     134
#
# [364627 rows x 9 columns]

# %%
# Merge to discharge, creating table of discharges with patient demographics
df_discharge_v4 = pd.merge(df_discharge_v3,
                           df_patients.loc[:, ['subject_id', 'gender', 'birth_year', 'offset']],
                           on='subject_id', how='left')

# Drop fields missing basic demographics
df_discharge_v4 = df_discharge_v4.dropna(subset=['gender', 'birth_year', 'offset'])
# Handle undesired type behavior
df_discharge_v4['birth_year'] = df_discharge_v4['birth_year'].astype(int)
df_discharge_v4['offset'] = df_discharge_v4['offset'].astype(int)
display(df_discharge_v4.info())

# Create new field indicating estimated true charttime
df_discharge_v4['date'] = df_discharge_v4.apply(lambda row: row['charttime'] - pd.DateOffset(years=row['offset']), axis=1)

# Calculate patient estimated age at time of encounter
df_discharge_v4['age'] = df_discharge_v4['date'].dt.year - df_discharge_v4['birth_year']

# Drop columns
df_discharge_v4 = df_discharge_v4.drop(['birth_year', 'offset', 'charttime'], axis=1)

# delete df
del df_patients
del df_discharge_v3

# Display
df_discharge_v4
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331761 entries, 0 to 331792
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   note_id            331761 non-null  object
#  1   subject_id         331761 non-null  int64
#  2   hadm_id            331761 non-null  int64
#  3   charttime          331761 non-null  datetime64[ns]
#  4   text               331761 non-null  object
#  5   ordered_diagnoses  331761 non-null  object
#  6   gender             331761 non-null  object
#  7   birth_year         331761 non-null  int64
#  8   offset             331761 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 25.3+ MB
# None
#                note_id  subject_id   hadm_id  \
# 0       10000032-DS-21    10000032  22595853
# 1       10000032-DS-22    10000032  22841357
# 2       10000032-DS-23    10000032  29079034
# 3       10000032-DS-24    10000032  25742920
# 4       10000084-DS-17    10000084  23052089
# ...                ...         ...       ...
# 331788   19999828-DS-6    19999828  29734428
# 331789   19999828-DS-7    19999828  25744818
# 331790  19999840-DS-20    19999840  26071774
# 331791  19999840-DS-21    19999840  21033226
# 331792   19999987-DS-2    19999987  23865745
#
#                                                      text  \
# 0        \nName:  ___                     Unit No:   _...
# 1        \nName:  ___                     Unit No:   _...
# 2        \nName:  ___                     Unit No:   _...
# 3        \nName:  ___                     Unit No:   _...
# 4        \nName:  ___                    Unit No:   __...
# ...                                                   ...
# 331788   \nName:  ___                   Unit No:   ___...
# 331789   \nName:  ___                   Unit No:   ___...
# 331790   \nName:  ___                  Unit No:   ___\...
# 331791   \nName:  ___                  Unit No:   ___\...
# 331792   \nName:  ___                    Unit No:   __...
#
#                                         ordered_diagnoses gender       date  \
# 0       [Portal hypertension, Other ascites, Cirrhosis...      F 2014-05-07
# 1       [Unspecified viral hepatitis C with hepatic co...      F 2014-06-27
# 2       [Other iatrogenic hypotension, Chronic hepatit...      F 2014-07-25
# 3       [Chronic hepatitis C without mention of hepati...      F 2014-08-07
# 4       [Neurocognitive disorder with Lewy bodies, Dem...      M 2017-11-25
# ...                                                   ...    ...        ...
# 331788  [Disruption of external operation (surgical) w...      F 2017-08-04
# 331789  [Infection following a procedure, superficial ...      F 2019-01-18
# 331790  [Cerebral artery occlusion, unspecified with c...      M 2008-07-28
# 331791  [Grand mal status, Acute respiratory failure, ...      M 2008-09-17
# 331792  [Intracerebral hemorrhage, Cerebral edema, Oth...      F 2011-11-11
#
#         age
# 0        52
# 1        52
# 2        52
# 3        52
# 4        72
# ...     ...
# 331788   46
# 331789   48
# 331790   58
# 331791   58
# 331792   57
#
# [331761 rows x 8 columns]

# %% [markdown]
# # 4. Load Radiology Data
# Radiology notes for patients. Not always associated with hospital admissions.

# %%
# Load data
df_rad = pd.read_csv(dir + '/radiology.csv')

# Convert charttime to pandas datetime
df_rad['charttime'] = pd.to_datetime(df_rad['charttime'], format='%Y-%m-%d %H:%M:%S')

# Convert NaN hadm_id to -1, then cast to int
df_rad['hadm_id'] = pd.to_numeric(df_rad['hadm_id'], errors='coerce').fillna(-1).astype(int)

# Rename columns to indicate radiology-specific
df_rad = df_rad.rename(columns={'charttime': 'rad_charttime', 'text': 'rad_desc'})

display(df_rad)
display(df_rad.info())
# Out:
#                 note_id  subject_id   hadm_id note_type  note_seq  \
# 0        10000032-RR-14    10000032  22595853        RR        14
# 1        10000032-RR-15    10000032  22595853        RR        15
# 2        10000032-RR-16    10000032  22595853        RR        16
# 3        10000032-RR-18    10000032        -1        RR        18
# 4        10000032-RR-20    10000032        -1        RR        20
# ...                 ...         ...       ...       ...       ...
# 2321350  19999987-RR-17    19999987  23865745        RR        17
# 2321351  19999987-RR-18    19999987  23865745        RR        18
# 2321352  19999987-RR-19    19999987  23865745        RR        19
# 2321353  19999987-RR-20    19999987  23865745        RR        20
# 2321354  19999987-RR-21    19999987  23865745        RR        21
#
#               rad_charttime            storetime  \
# 0       2180-05-06 21:19:00  2180-05-06 23:32:00
# 1       2180-05-06 23:00:00  2180-05-06 23:26:00
# 2       2180-05-07 09:55:00  2180-05-07 11:15:00
# 3       2180-06-03 12:46:00  2180-06-03 14:01:00
# 4       2180-07-08 13:18:00  2180-07-08 14:15:00
# ...                     ...                  ...
# 2321350 2145-11-02 22:37:00  2145-11-03 18:55:00
# 2321351 2145-11-03 04:35:00  2145-11-03 10:46:00
# 2321352 2145-11-03 16:40:00  2145-11-04 08:36:00
# 2321353 2145-11-04 05:10:00  2145-11-04 08:58:00
# 2321354 2145-11-07 15:18:00  2145-11-08 16:44:00
#
#                                                   rad_desc
# 0        EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION...
# 1        EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE ...
# 2        INDICATION:  ___ HCV cirrhosis c/b ascites, hi...
# 3        EXAMINATION:  Ultrasound-guided paracentesis.\...
# 4        EXAMINATION:  Paracentesis\n\nINDICATION:  ___...
# ...                                                    ...
# 2321350  HISTORY:  ___, with left occipital bleeding.  ...
# 2321351  INDICATION:  ___ female intubated for head ble...
# 2321352  HISTORY:  ___ woman with left occipital hemorr...
# 2321353  PORTABLE CHEST OF ___\n\nCOMPARISON:  ___ radi...
# 2321354  DATE OF SERVICE:  ___.\n\nPRE-OPERATIVE DIAGNO...
#
# [2321355 rows x 8 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2321355 entries, 0 to 2321354
# Data columns (total 8 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   note_id        object
#  1   subject_id     int64
#  2   hadm_id        int64
#  3   note_type      object
#  4   note_seq       int64
#  5   rad_charttime  datetime64[ns]
#  6   storetime      object
#  7   rad_desc       object
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 141.7+ MB
# None

# %% [markdown]
# ## Aggregate Rad Reports

# %%
# Join radiology reports by subject and admission
df_aggregate_rad_desc = pd.merge(df_discharge_v4,
                            df_rad.loc[:, ['subject_id', 'hadm_id', 'rad_charttime', 'rad_desc']],
                            on=['subject_id', 'hadm_id'], how='left')

# Sort by subject_hadm and priority
df_aggregate_rad_desc = df_aggregate_rad_desc.sort_values(['subject_id', 'hadm_id', 'rad_charttime'])

# Retain only the top n
n_rad_priority = 5  #TODO
df_aggregate_rad_desc = df_aggregate_rad_desc.groupby(['subject_id', 'hadm_id']).head(n_rad_priority).reset_index(drop=True)

# Aggregate diagnosis texts into a list, ordered by priority
df_aggregate_rad_desc = df_aggregate_rad_desc.groupby(['subject_id', 'hadm_id'])['rad_desc'].apply(list).reset_index(name='ordered_rad')

df_aggregate_rad_desc.head()
# Out:
#    subject_id   hadm_id                                        ordered_rad
# 0    10000032  22595853  [EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATIO...
# 1    10000032  22841357  [EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE...
# 2    10000032  25742920  [INDICATION:  ___ year old woman with cirrhosi...
# 3    10000032  29079034  [EXAMINATION:  CT HEAD W/O CONTRAST\n\nINDICAT...
# 4    10000084  23052089                                              [nan]

# %%
# Join aggregate rad reports to discharge table
df_discharge_v5 = pd.merge(df_discharge_v4,
                            df_aggregate_rad_desc,
                            on=['subject_id', 'hadm_id'], how='left')

df_discharge_v5.head()
# Out:
#           note_id  subject_id   hadm_id  \
# 0  10000032-DS-21    10000032  22595853
# 1  10000032-DS-22    10000032  22841357
# 2  10000032-DS-23    10000032  29079034
# 3  10000032-DS-24    10000032  25742920
# 4  10000084-DS-17    10000084  23052089
#
#                                                 text  \
# 0   \nName:  ___                     Unit No:   _...
# 1   \nName:  ___                     Unit No:   _...
# 2   \nName:  ___                     Unit No:   _...
# 3   \nName:  ___                     Unit No:   _...
# 4   \nName:  ___                    Unit No:   __...
#
#                                    ordered_diagnoses gender       date  age  \
# 0  [Portal hypertension, Other ascites, Cirrhosis...      F 2014-05-07   52
# 1  [Unspecified viral hepatitis C with hepatic co...      F 2014-06-27   52
# 2  [Other iatrogenic hypotension, Chronic hepatit...      F 2014-07-25   52
# 3  [Chronic hepatitis C without mention of hepati...      F 2014-08-07   52
# 4  [Neurocognitive disorder with Lewy bodies, Dem...      M 2017-11-25   72
#
#                                          ordered_rad
# 0  [EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATIO...
# 1  [EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE...
# 2  [EXAMINATION:  CT HEAD W/O CONTRAST\n\nINDICAT...
# 3  [INDICATION:  ___ year old woman with cirrhosi...
# 4                                              [nan]

# %% [markdown]
# # 5. Clean

# %%
# Reorder columns for clarity
display(df_discharge_v5.columns)

df_discharge_v5 = df_discharge_v5.reindex(columns=[
    'note_id',
    'subject_id',
    'hadm_id',
    'gender',
    'age',
    'date',
    'text',
    'ordered_rad',
    'ordered_diagnoses'])

df_discharge_v5
# Out:
# Index(['note_id', 'subject_id', 'hadm_id', 'text', 'ordered_diagnoses',
#        'gender', 'date', 'age', 'ordered_rad'],
#       dtype='object')
#                note_id  subject_id   hadm_id gender  age       date  \
# 0       10000032-DS-21    10000032  22595853      F   52 2014-05-07
# 1       10000032-DS-22    10000032  22841357      F   52 2014-06-27
# 2       10000032-DS-23    10000032  29079034      F   52 2014-07-25
# 3       10000032-DS-24    10000032  25742920      F   52 2014-08-07
# 4       10000084-DS-17    10000084  23052089      M   72 2017-11-25
# ...                ...         ...       ...    ...  ...        ...
# 331756   19999828-DS-6    19999828  29734428      F   46 2017-08-04
# 331757   19999828-DS-7    19999828  25744818      F   48 2019-01-18
# 331758  19999840-DS-20    19999840  26071774      M   58 2008-07-28
# 331759  19999840-DS-21    19999840  21033226      M   58 2008-09-17
# 331760   19999987-DS-2    19999987  23865745      F   57 2011-11-11
#
#                                                      text  \
# 0        \nName:  ___                     Unit No:   _...
# 1        \nName:  ___                     Unit No:   _...
# 2        \nName:  ___                     Unit No:   _...
# 3        \nName:  ___                     Unit No:   _...
# 4        \nName:  ___                    Unit No:   __...
# ...                                                   ...
# 331756   \nName:  ___                   Unit No:   ___...
# 331757   \nName:  ___                   Unit No:   ___...
# 331758   \nName:  ___                  Unit No:   ___\...
# 331759   \nName:  ___                  Unit No:   ___\...
# 331760   \nName:  ___                    Unit No:   __...
#
#                                               ordered_rad  \
# 0       [EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATIO...
# 1       [EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE...
# 2       [EXAMINATION:  CT HEAD W/O CONTRAST\n\nINDICAT...
# 3       [INDICATION:  ___ year old woman with cirrhosi...
# 4                                                   [nan]
# ...                                                   ...
# 331756  [INDICATION:  ___ year old woman with new righ...
# 331757  [EXAMINATION:  UNILAT LOWER EXT VEINS RIGHT\n\...
# 331758  [HISTORY:  Seizure and fever.\n\nFINDINGS:  Fr...
# 331759  [INDICATION:  ___ man with seizure and elevate...
# 331760  [CHEST RADIOGRAPH PERFORMED ON ___\n\nCOMPARIS...
#
#                                         ordered_diagnoses
# 0       [Portal hypertension, Other ascites, Cirrhosis...
# 1       [Unspecified viral hepatitis C with hepatic co...
# 2       [Other iatrogenic hypotension, Chronic hepatit...
# 3       [Chronic hepatitis C without mention of hepati...
# 4       [Neurocognitive disorder with Lewy bodies, Dem...
# ...                                                   ...
# 331756  [Disruption of external operation (surgical) w...
# 331757  [Infection following a procedure, superficial ...
# 331758  [Cerebral artery occlusion, unspecified with c...
# 331759  [Grand mal status, Acute respiratory failure, ...
# 331760  [Intracerebral hemorrhage, Cerebral edema, Oth...
#
# [331761 rows x 9 columns]

# %% [markdown]
# # Sample for annotation
# - Sample 50 rows for annotation

# %%
annotate_discharge_sample = df_discharge_v5.sample(50, random_state=35).reset_index(drop=True)
display(annotate_discharge_sample)

# Save as csv
annotate_discharge_sample.to_csv(dir + '/annotate_discharge_sample.csv', index=True)
# Out:
#            note_id  subject_id   hadm_id gender  age       date  \
# 0    18367270-DS-6    18367270  28706071      F   30 2017-10-01
# 1    18234943-DS-7    18234943  22128361      F   53 2014-05-22
# 2    19011334-DS-6    19011334  28892047      M   78 2014-07-30
# 3   18826698-DS-15    18826698  20922553      M   60 2012-02-01
# 4   14066157-DS-39    14066157  26888351      M   68 2009-07-20
# 5   13973494-DS-17    13973494  26551541      M   63 2018-04-06
# 6    18511092-DS-9    18511092  28348890      M   61 2017-09-25
# 7   18922533-DS-16    18922533  23499660      F   81 2017-02-19
# 8    12018806-DS-3    12018806  22957216      M   35 2014-09-18
# 9   17414848-DS-15    17414848  20465956      F   78 2017-11-08
# 10   18696269-DS-6    18696269  21775171      F   91 2014-06-18
# 11   11594544-DS-7    11594544  22202217      F   71 2011-08-15
# 12  18567979-DS-37    18567979  20604188      F   92 2012-08-01
# 13  18284271-DS-65    18284271  20609319      F   76 2016-12-12
# 14  17434499-DS-20    17434499  28993540      F   26 2010-10-13
# 15  19011460-DS-20    19011460  29810802      F   78 2017-09-22
# 16  18836535-DS-17    18836535  21135544      M   72 2018-05-09
# 17   13043521-DS-8    13043521  26582764      F   58 2017-04-09
# 18   15900945-DS-3    15900945  20338500      F   47 2017-11-14
# 19  11401045-DS-21    11401045  29315809      F   77 2017-05-30
# 20   10112559-DS-7    10112559  24894485      F   43 2019-06-12
# 21  15942934-DS-58    15942934  21716982      F   66 2009-11-10
# 22  16421179-DS-13    16421179  29473437      F   93 2010-08-21
# 23  15666511-DS-27    15666511  22434396      F   25 2016-12-14
# 24   15862014-DS-7    15862014  26390119      M   86 2012-08-20
# 25  12288867-DS-15    12288867  26382217      M   87 2017-04-13
# 26  12698610-DS-10    12698610  29134586      M   67 2011-08-21
# 27  18696623-DS-17    18696623  29075620      F   67 2018-10-24
# 28  11992252-DS-15    11992252  21906103      M   70 2017-11-14
# 29  18036188-DS-19    18036188  20380495      F   80 2011-05-19
# 30  14048242-DS-24    14048242  25626107      M   69 2015-06-24
# 31  18578198-DS-14    18578198  24127525      F   28 2017-06-10
# 32  16733975-DS-15    16733975  20484791      M   51 2009-03-23
# 33  13505226-DS-38    13505226  27062850      M   39 2015-04-09
# 34  10292730-DS-23    10292730  27340445      F   94 2020-03-06
# 35  16353780-DS-13    16353780  20538178      F   79 2017-08-24
# 36  16625317-DS-13    16625317  21013960      F   59 2012-02-19
# 37  16097039-DS-13    16097039  22469368      M   67 2013-02-25
# 38  14691904-DS-14    14691904  28837780      M   52 2017-11-01
# 39  14249944-DS-16    14249944  27867166      F   70 2017-09-11
# 40  10260854-DS-13    10260854  24738129      F   48 2009-04-19
# 41   13459260-DS-8    13459260  25855024      F   63 2008-08-16
# 42  18209122-DS-22    18209122  26636501      M   47 2012-03-29
# 43  11745281-DS-21    11745281  29196612      M   53 2008-12-13
# 44  18757293-DS-21    18757293  25052678      M   77 2008-09-20
# 45  15588294-DS-13    15588294  25524359      M   30 2010-05-31
# 46  18202651-DS-15    18202651  29452495      F   75 2014-07-16
# 47  13591594-DS-13    13591594  25884109      M   77 2011-09-16
# 48  19757915-DS-14    19757915  25993053      F   89 2011-12-28
# 49  16421457-DS-19    16421457  29471205      M   58 2014-11-24
#
#                                                  text  \
# 0    \nName:  ___               Unit No:   ___\n \...
# 1    \nName:  ___                    Unit No:   __...
# 2    \nName:  ___                      Unit No:   ...
# 3    \nName:  ___                   Unit No:   ___...
# 4    \nName:  ___                Unit No:   ___\n ...
# 5    \nName:  ___              Unit No:   ___\n \n...
# 6    \nName:  ___                   Unit No:   ___...
# 7    \nName:  ___                    Unit No:   __...
# 8    \nName:  ___                  Unit No:   ___\...
# 9    \nName:  ___                   Unit No:   ___...
# 10   \nName:  ___                  Unit No:   ___\...
# 11   \nName:  ___                  Unit No:   ___\...
# 12   \nName:  ___.                  Unit No:   ___...
# 13   \nName:  ___             Unit No:   ___\n \nA...
# 14   \nName:  ___                 Unit No:   ___\n...
# 15   \nName:  ___                 Unit No:   ___\n...
# 16   \nName:  ___                    Unit No:   __...
# 17   \nName:  ___                   Unit No:   ___...
# 18   \nName:  ___               Unit No:   ___\n \...
# 19   \nName:  ___               Unit No:   ___\n \...
# 20   \nName:  ___                 Unit No:   ___\n...
# 21   \nName:  ___                     Unit No:   _...
# 22   \nName:  ___                   Unit No:   ___...
# 23   \nName:  ___                Unit No:   ___\n ...
# 24   \nName:  ___                   Unit No:   ___...
# 25   \nName:  ___               Unit No:   ___\n \...
# 26   \nName:  ___                  Unit No:   ___\...
# 27   \nName:  ___                     Unit No:   _...
# 28   \nName:  ___          Unit No:   ___\n \nAdmi...
# 29   \nName:  ___                Unit No:   ___\n ...
# 30   \nName:  ___                Unit No:   ___\n ...
# 31   \nName:  ___                   Unit No:   ___...
# 32   \nName:  ___                    Unit No:   __...
# 33   \nName:  ___                  Unit No:   ___\...
# 34   \nName:  ___                    Unit No:   __...
# 35   \nName:  ___                   Unit No:   ___...
# 36   \nName:  ___               Unit No:   ___\n \...
# 37   \nName:  ___                  Unit No:   ___\...
# 38   \nName:  ___        ___ No:   ___\n \nAdmissi...
# 39   \nName:  ___               Unit No:   ___\n \...
# 40   \nName:  ___                   Unit No:   ___...
# 41   \nName:  ___                     Unit No:   _...
# 42   \nName:  ___                    Unit No:   __...
# 43   \nName:  ___                    Unit No:   __...
# 44   \nName:  ___                    Unit No:   __...
# 45   \nName:  ___                  Unit No:   ___\...
# 46   \nName:  ___              Unit No:   ___\n \n...
# 47   \nName:  ___                   Unit No:   ___...
# 48   \nName:  ___                    ___ No:   ___...
# 49   \nName:  ___                   Unit No:   ___...
#
#                                           ordered_rad  \
# 0   [EXAMINATION:  MR HEAD W AND W/O CONTRAST T___...
# 1   [HISTORY:  Cough and fever \n\nCOMPARISON:  No...
# 2                                               [nan]
# 3                                               [nan]
# 4   [INDICATION:  Rigors and fever.\n\nCOMPARISON:...
# 5   [INDICATION:   ___ with unsteadiness, vomiting...
# 6   [EXAMINATION:  CT HEAD W/O CONTRAST\n\nINDICAT...
# 7                                               [nan]
# 8   [EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE...
# 9   [EXAMINATION:  CHEST (AP AND LAT)\n\nINDICATIO...
# 10  [EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATIO...
# 11  [HISTORY:  ___ female with CHF.\n\nCOMPARISON:...
# 12  [EXAM:  Chest frontal and lateral views.\n\nCL...
# 13                                              [nan]
# 14  [REASON FOR EXAMINATION:  New central venous l...
# 15  [EXAMINATION:  CHEST (PORTABLE AP)\n\nINDICATI...
# 16  [EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE...
# 17  [EXAMINATION:  ABDOMEN US (COMPLETE STUDY)\n\n...
# 18                                              [nan]
# 19  [EXAMINATION:  MR HEAD W AND W/O CONTRAST T___...
# 20                                              [nan]
# 21  [INDICATION:  ___ woman with fever and history...
# 22  [INDICATION:  ___ female with hypoxia, evaluat...
# 23  [EXAMINATION:  US-guided diagnostic and therap...
# 24  [EXAMINATION:  CT ABD AND PELVIS\n\nINDICATION...
# 25  [EXAMINATION:\nChest:  Frontal and lateral vie...
# 26  [HISTORY:  Evaluation of patient with history ...
# 27  [INDICATION:  ___ year old woman with recent _...
# 28  [EXAMINATION:  CHEST (SINGLE VIEW)\n\nINDICATI...
# 29  [HISTORY:  ___ female with percutaneous cholec...
# 30  [EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATIO...
# 31  [EXAMINATION:  MR HEAD W/ CONTRAST T9115 MR HE...
# 32  [SUPINE AND UPRIGHT ABDOMEN, ___, AT 11:02 A.M...
# 33  [EXAMINATION:  CT of the abdomen and pelvis wi...
# 34  [EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATIO...
# 35  [ADDENDUM  The patient experienced an allergic...
# 36  [INDICATION:  ___ year old woman with ESRD wit...
# 37  [EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATIO...
# 38  [EXAMINATION:  CHEST (PORTABLE AP)\n\nINDICATI...
# 39                                              [nan]
# 40  [HISTORY:  ___ female presenting for intrathec...
# 41  [HISTORY:  Fracture.  Hardware removal.\n\nTwo...
# 42                                              [nan]
# 43  [LEFT ELBOW THREE VIEWS, ___ AT 13:18 HOURS\n\...
# 44  [HISTORY:  Trauma, fall, complaining of left w...
# 45  [HISTORY:  Male with history of chronic pancre...
# 46  [EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATIO...
# 47  [HISTORY:  Preoperative for CABG.\n\nFINDINGS:...
# 48  [INDICATION:  New onset shortness of breath, a...
# 49  [EXAMINATION:  CHEST (PORTABLE AP)\n\nINDICATI...
#
#                                     ordered_diagnoses
# 0   [Other specified congenital malformations of b...
# 1   [Asthma, unspecified type, unspecified, Hypoxe...
# 2   [Calculus of bile duct without cholangitis or ...
# 3   [Abdominal pain, periumbilic, Localization-rel...
# 4   [Acute kidney failure, unspecified, Acute on c...
# 5   [Other peripheral vertigo, unspecified ear, Un...
# 6   [ST elevation (STEMI) myocardial infarction in...
# 7   [Other nontraumatic intracerebral hemorrhage, ...
# 8   [Alcoholic cirrhosis of liver with ascites, Se...
# 9   [Sepsis due to Escherichia coli [E. coli], End...
# 10  [Urinary tract infection, site not specified, ...
# 11  [Acute on chronic systolic heart failure, Diab...
# 12  [Esophageal reflux, Coronary atherosclerosis o...
# 13  [Varicose veins of unspecified lower extremity...
# 14  [Attention to ileostomy, nan, Paralytic ileus,...
# 15  [Hallucinations, unspecified, Disorientation, ...
# 16  [Calculus of gallbladder with acute cholecysti...
# 17  [Acute and subacute hepatic failure without co...
# 18  [Leiomyoma of uterus, unspecified, nan, Other ...
# 19  [Benign neoplasm of cerebral meninges, Cerebra...
# 20  [Calculus of bile duct without cholangitis or ...
# 21  [Other and unspecified infection due to centra...
# 22  [Pneumonia, organism unspecified, Acute respir...
# 23  [Sepsis due to Escherichia coli [E. coli], Spo...
# 24  [Contusion of hip, Atrial fibrillation, Chroni...
# 25  [Atherosclerotic heart disease of native coron...
# 26  [Hyperpotassemia, Acute kidney failure, unspec...
# 27  [Disruption of internal operation (surgical) w...
# 28  [Ulcer of esophagus without bleeding, Divertic...
# 29  [Streptococcal septicemia, End stage renal dis...
# 30  [Acute bronchitis, unspecified, Other asthma, ...
# 31  [Benign neoplasm of cerebral meninges, Acute p...
# 32  [Intestinal or peritoneal adhesions with obstr...
# 33  [Melena, Essential (primary) hypertension, Lef...
# 34  [Hypertensive heart and chronic kidney disease...
# 35  [Nonrheumatic aortic (valve) stenosis, Anesthe...
# 36  [Encounter for extracorporeal dialysis, End st...
# 37  [Coronary atherosclerosis of native coronary a...
# 38  [Nontraumatic subarachnoid hemorrhage from ant...
# 39  [Malignant neoplasm of unspecified ovary, Seco...
# 40  [Neoplasm related pain (acute) (chronic), Mali...
# 41  [Other mechanical complication of other intern...
# 42  [Alcohol withdrawal, Other and unspecified alc...
# 43                               [Olecranon bursitis]
# 44  [Closed fracture of base of skull without ment...
# 45  [Chronic pancreatitis, Tobacco use disorder, A...
# 46  [Non-ST elevation (NSTEMI) myocardial infarcti...
# 47  [Coronary atherosclerosis of native coronary a...
# 48  [Ulcer of other part of lower limb, Chronic di...
# 49  [Atherosclerotic heart disease of native coron...
